# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import datetime as dt

# %%
path = 'data_research.csv'
dataframe = pd.read_csv(path)

dataframe = dataframe.set_index("Date")
dataframe.index = pd.to_datetime(dataframe.index)

# %%
dataframe
# Out:
#                NER     RER  Fedfunds      PPI    Indpro   Borrow
# Date
# 1964-01-01  138.91  146.62      3.48   39.900   27.8086   0.2743
# 1964-02-01  138.93  146.14      3.48   39.100   27.9972   0.2863
# 1964-03-01  138.90  145.93      3.43   39.400   27.9972   0.2777
# 1964-04-01  138.94  145.14      3.47   39.100   28.4553   0.2110
# 1964-05-01  143.83  149.19      3.50   38.800   28.6170   0.2601
# ...            ...     ...       ...      ...       ...      ...
# 2022-03-01  118.96  130.18      0.20  250.299  103.6218  26.2058
# 2022-04-01  121.16  131.31      0.33  261.884  104.3022  23.9603
# 2022-05-01  123.94  134.17      0.77  263.817  104.2103  21.8827
# 2022-06-01  124.80  135.80      1.21  261.343  104.2229  21.4228
# 2022-07-01  127.74  138.69      1.68  255.465  104.8075      NaN
#
# [703 rows x 6 columns]

# %%
import datetime

# %%
fig = plt.figure(figsize = (8,4))

x1 = fig.add_subplot()
dataframe['NER'].plot(ax=x1, label='NER', color='black')
plt.xlabel('\nTỷ giá hối đoái đa phương (danh nghĩa) và Lãi suất của FED', fontsize=12)
plt.legend(loc=1)

x2 = x1.twinx()
dataframe['Fedfunds'].plot(ax=x2, label='Fedfunds')
plt.legend(loc=1, bbox_to_anchor=(1,0.9))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize = (8,4))

x1 = fig.add_subplot()
dataframe['RER'].plot(ax=x1, label='RER', color='black')
plt.xlabel('\nTỷ giá hối đoái đa phương (thực) và Lãi suất của FED', fontsize=12)
plt.legend(loc=1)

x2 = x1.twinx()
dataframe['Fedfunds'].plot(ax=x2, label='Fedfunds')
plt.legend(loc=1, bbox_to_anchor=(1,0.9))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize = (8,4))

x1 = fig.add_subplot()
dataframe['Borrow'].plot(ax=x1, label='Borrow', color='black')
plt.xlabel('\nTổng vay của các tổ chức lưu ý và Lãi suất của FED', fontsize=12)
plt.legend(loc=1)

x2 = x1.twinx()
dataframe['Fedfunds'].plot(ax=x2, label='Fedfunds')
plt.legend(loc=1, bbox_to_anchor=(1,0.9))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize = (8,4))

x1 = fig.add_subplot()
dataframe['PPI'].plot(ax=x1, label='PPI', color='black')
plt.xlabel('\nChỉ số sản xuất công nghiệp (nhóm ngành nông nghiệp) và Lãi suất của FED', fontsize=12)
plt.legend(loc=1)

x2 = x1.twinx()
dataframe['Fedfunds'].plot(ax=x2, label='Fedfunds')
plt.legend(loc=1, bbox_to_anchor=(1,0.9))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize = (8,4))

x1 = fig.add_subplot()
dataframe['Indpro'].plot(ax=x1, label='Indpro', color='black')
plt.xlabel('\nTổng chỉ số sản xuất công nghiệp và Lãi suất của FED', fontsize=12)
plt.legend(loc=2)

x2 = x1.twinx()
dataframe['Fedfunds'].plot(ax=x2, label='Fedfunds')
plt.legend(loc=2, bbox_to_anchor=(-0.008,0.9))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
